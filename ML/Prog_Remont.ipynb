# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install xlrd

# %% [markdown]
# Выгрузка и чтение датасет X_1

# %%
X_1_xlsx = 'E:\Data10\X_1.xlsx'

# %%
X_1 = pd.read_excel(X_1_xlsx, engine = 'openpyxl')

# %% [markdown]
# Проверка размерности датасета

# %%
X_1.shape
# Out:
# (18433, 32)

# %% [markdown]
# Вывод первых 5 строк датасета X_1

# %%
print(X_1.head())
# Out:
#           ID                                       NAME  PARENT_ID      LOGIN  \
# 0        NaN                                        NaN        NaN        NaN
# 1  1500923.0      Дом по адресу Красковская ул., д.121А        NaN         WS
# 2  1500933.0   Дом по адресу Байкальская ул., д.18, к.2        NaN         WS
# 3  1500943.0          Дом по адресу Перовская ул., д.48        NaN         WS
# 4  1500951.0  Дом по адресу Парковая 3-я ул., д.39, к.3        NaN  404070001
#
#       COL_754              COL_755        COL_756            COL_757  \
# 0  Назначение  Форма собственности  Год постройки  Год реконструкции
# 1         NaN                  NaN           1956                NaN
# 2         NaN                  NaN           2005                NaN
# 3         NaN                  NaN           1955                NaN
# 4         NaN                  NaN           1960                NaN
#
#          COL_758            COL_759  ...                    COL_775  \
# ...

# %% [markdown]
# Вывод общей информации о X_1

# %%
X_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18433 entries, 0 to 18432
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          18432 non-null  float64
#  1   NAME        18432 non-null  object
#  2   PARENT_ID   22 non-null     float64
#  3   LOGIN       18432 non-null  object
#  4   COL_754     4156 non-null   object
#  5   COL_755     1 non-null      object
#  6   COL_756     18375 non-null  object
#  7   COL_757     2 non-null      object
#  8   COL_758     18374 non-null  object
#  9   COL_759     18375 non-null  object
#  10  COL_760     18354 non-null  object
#  11  COL_761     5618 non-null   object
#  12  COL_762     18374 non-null  object
#  13  COL_763     18356 non-null  object
#  14  COL_764     18356 non-null  object
#  15  COL_765     715 non-null    object
#  16  COL_766     715 non-null    object
#  17  COL_767     1 non-null      object
#  18  COL_769     18374 non-null  object
# ...

# %% [markdown]
# Подсчет количества пропущенных значений в каждом столбце

# %%
X_1.isna().sum()
# Out:
# ID                1
# NAME              1
# PARENT_ID     18411
# LOGIN             1
# COL_754       14277
# COL_755       18432
# COL_756          58
# COL_757       18431
# COL_758          59
# COL_759          58
# COL_760          79
# COL_761       12815
# COL_762          59
# COL_763          77
# COL_764          77
# COL_765       17718
# COL_766       17718
# COL_767       18432
# COL_769          59
# COL_770       12759
# COL_771          74
# COL_772          74
# COL_775       16304
# COL_781       12833
# COL_782           0
# COL_2156      18432
# COL_2463      12585
# COL_3163          0
# COL_3243      13849
# COL_3363         79
# COL_3468      18364
# COL_103506    18432
# dtype: int64

# %% [markdown]
# Количестово значений ноль в каждом столбце

# %%
#zero_counts = (X_1 ==0).sum()

# %%
#zero_counts = X_1.apply(lambda x: x == 0).sum()

# %%
#print(zero_counts)

# %% [markdown]
# Выгрузка датасет X_2

# %%
X_2_xlsx = 'E:\Data10\X_2.xlsx'

# %%
X_2 = pd.read_excel(X_2_xlsx, engine = 'openpyxl')

# %% [markdown]
# Проверка размерности

# %%
X_2.shape
# Out:
# (1048575, 8)

# %%
X_2['Дата создания во внешней системе'] = X_2['Дата создания во внешней системе'].str.extract('(\d{4}-\d{2}-\d{2})')

# %%
X_2['Дата создания во внешней системе'] = pd.to_datetime(X_2['Дата создания во внешней системе']).dt.date

# %% [markdown]
# Вывод первых 5 строк датасета Х_2

# %%
print(X_2.head())
# Out:
#                                    Наименование Источник  \
# 0                                Открыт колодец      MVK
# 1  Отклонение ГВС ниже нормы ночью (мониторинг)    ASUPR
# 2   Отклонение ГВС ниже нормы днем (мониторинг)    ASUPR
# 3                    Температура ГВС ниже нормы    ASUPR
# 4                    Температура ГВС ниже нормы    ASUPR
#
#   Дата создания во внешней системе               Дата закрытия Округ  \
# 0                       2022-08-30  2022-08-30 15:40:26.565000   ВАО
# 1                       2022-02-20  2022-04-04 02:43:22.101000   ВАО
# 2                       2022-03-07  2022-03-09 09:33:24.894000   ВАО
# 3                       2022-03-05  2022-03-05 19:14:00.190000   ВАО
# 4                       2022-02-18  2022-02-18 18:44:14.682000   ВАО
#
#                                                Адрес     unom  \
# 0  внутригородская территория муниципальный округ...  2115191
# 1  внутригородская территория муниципальный округ...  2404461
# ...

# %% [markdown]
# Добавить префикс к значению в столбце 'Адрес'

# %%
prefix = "Российская Федерация, город Москва, "
X_2['Адрес'] = prefix + X_2['Адрес']

# %% [markdown]
# Вывод общей информации по X_2

# %%
X_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Наименование                        1048532 non-null  object
#  1   Источник                            1048575 non-null  object
#  2   Дата создания во внешней системе    1048575 non-null  object
#  3   Дата закрытия                       1048574 non-null  object
#  4   Округ                               1048575 non-null  object
#  5   Адрес                               1048575 non-null  object
#  6   unom                                1048575 non-null  int64
#  7   Дата и время завершения события во  302806 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 64.0+ MB

# %% [markdown]
# Высести уникальные значения столбца Наименование

# %%
unique_values = X_2['Наименование'].unique()

# %% [markdown]
# Для вывода уникальных значений на печать

# %%
for value in unique_values:
    print(value)
# Out:
# Открыт колодец
# Отклонение ГВС ниже нормы ночью (мониторинг)
# Отклонение ГВС ниже нормы днем (мониторинг)
# Температура ГВС ниже нормы
# Отсутствует циркуляция ГВС
# T1 > max
# Изменение конфигурации УСПД
# Расхождение времени ПУ
# Критичное отклонение температуры ГВС ниже нормы днем (мониторинг)
# Низкий уровень сигнала GSM
# Нет связи с ПУ
# Отсутствуют актуальные суточные значения
# Отсутствуют актуальные мгновенные значения
# Критичное отклонение температуры ГВС ниже нормы ночью (мониторинг)
# Нет питания УСПД
# Открыт шкаф УСПД
# Нет связи с УСПД
# Угроза взрыва
# Отсутствие освещения в местах общего пользования
# Загрязнение/замусоренность подъезда
# Повреждение системы электропроводки/щитового оборудования
# Повреждение отделочных покрытий пола/стены/ступеней/перил/других элементов
# Загрязнение воды
# Повреждение элементов входной двери
# Повреждение элементов фасада
# Отсутствие ХВС в доме
# Загрязнение лифта
# Неочищенная кровля
# Засор мусоропровода
# ...

# %%
print(X_2.head())
# Out:
#                                    Наименование Источник  \
# 0                                Открыт колодец      MVK
# 1  Отклонение ГВС ниже нормы ночью (мониторинг)    ASUPR
# 2   Отклонение ГВС ниже нормы днем (мониторинг)    ASUPR
# 3                    Температура ГВС ниже нормы    ASUPR
# 4                    Температура ГВС ниже нормы    ASUPR
#
#   Дата создания во внешней системе               Дата закрытия Округ  \
# 0                       2022-08-30  2022-08-30 15:40:26.565000   ВАО
# 1                       2022-02-20  2022-04-04 02:43:22.101000   ВАО
# 2                       2022-03-07  2022-03-09 09:33:24.894000   ВАО
# 3                       2022-03-05  2022-03-05 19:14:00.190000   ВАО
# 4                       2022-02-18  2022-02-18 18:44:14.682000   ВАО
#
#                                                Адрес     unom  \
# 0  Российская Федерация, город Москва, внутригоро...  2115191
# 1  Российская Федерация, город Москва, внутригоро...  2404461
# ...

# %%
grouped_X_2= X_2.groupby('unom')['Наименование'].size().reset_index(name='Инциндент')

# %%
print(grouped_X_2)
# Out:
#          unom  Инциндент
# 0         308         29
# 1         309        540
# 2         310         33
# 3         311         23
# 4         312        155
# ...       ...        ...
# 6710  5281829          4
# 6711  5283529          7
# 6712  5286357          2
# 6713  5288995          1
# 6714  5289239          1
#
# [6715 rows x 2 columns]

# %%
grouped.to_excel("E:\Data10\grouped_X_2.xlsx", index=False)

# %% [markdown]
# Подсчет количества пропущенных значений в каждом столбце

# %%
#X_2.isna().sum()

# %%
X_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Наименование                        1048532 non-null  object
#  1   Источник                            1048575 non-null  object
#  2   Дата создания во внешней системе    1048575 non-null  object
#  3   Дата закрытия                       1048574 non-null  object
#  4   Округ                               1048575 non-null  object
#  5   Адрес                               1048575 non-null  object
#  6   unom                                1048575 non-null  int64
#  7   Дата и время завершения события во  302806 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 64.0+ MB

# %%
X_2['Дата создания во внешней системе'] = X_2['Дата создания во внешней системе'].astype(str)

# %%
X_2.to_excel('E:\Data10\X_2_11.xlsx', index=False, engine='openpyxl')

# %% [markdown]
# Выгрузка датасет X_3

# %%
X_3_xlsx = 'E:\Data10\X_3.xlsx'

# %%
X_3 = pd.read_excel(X_3_xlsx, engine = 'openpyxl')

# %% [markdown]
# Проверка размерности датасета

# %%
X_3.shape
# Out:
# (1747, 13)

# %% [markdown]
# Вывод первых 5 строк датасета

# %%
print(X_3.head())
# Out:
#    global_id  PERIOD                                          WORK_NAME  \
# 0     351060    2022                      замена лифтового оборудования
# 1     430496    2022                      замена лифтового оборудования
# 2     348580    2022  ремонт внутридомовых инженерных систем водоотв...
# 3     348581    2022  ремонт внутридомовых инженерных систем теплосн...
# 4     348578    2022  ремонт внутридомовых инженерных систем холодно...
#
#    NUM_ENTRANCE ElevatorNumber PLAN_DATE_START PLAN_DATE_END FACT_DATE_START  \
# 0           1.0              1      15.07.2022    28.08.2022      27.06.2022
# 1           1.0              1      30.09.2022    14.10.2022      30.09.2022
# 2           NaN            NaN      21.02.2022    20.06.2022      01.02.2022
# 3           NaN            NaN      21.04.2022    10.07.2022      07.05.2022
# 4           NaN            NaN      21.02.2022    20.06.2022      01.02.2022
#
# ...

# %% [markdown]
# Вывод общей информации по датасету

# %%
X_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747 entries, 0 to 1746
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   global_id        1747 non-null   int64
#  1   PERIOD           1747 non-null   int64
#  2   WORK_NAME        1747 non-null   object
#  3   NUM_ENTRANCE     285 non-null    float64
#  4   ElevatorNumber   285 non-null    object
#  5   PLAN_DATE_START  1747 non-null   object
#  6   PLAN_DATE_END    1747 non-null   object
#  7   FACT_DATE_START  1747 non-null   object
#  8   FACT_DATE_END    1747 non-null   object
#  9   AdmArea          1747 non-null   object
#  10  District         1747 non-null   object
#  11  Address          1747 non-null   object
#  12  UNOM             1747 non-null   int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 177.6+ KB

# %% [raw]
# Преобразование столбец 'Преобразуем столбец ' в формат datetime' в формат datetime

# %%
X_3 ['PLAN_DATE_START'] = X_3 ['PLAN_DATE_START'].dt.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34908\3306981155.py in <module>
# ----> 1 X_3 ['PLAN_DATE_START'] = X_3 ['PLAN_DATE_START'].dt.strftime('%Y-%m-%d')
#
# NameError: name 'X_3' is not defined

# %%
X_3 ['PLAN_DATE_START'] = pd.to_datetime(X_3 ['PLAN_DATE_START'])

# %% [markdown]
# Преобразование формата даты в 'YYYY-MM-DD'

# %%
X_3 ['PLAN_DATE_START'] = pd.to_datetime(X_3 ['PLAN_DATE_START'])

# %%
print(X_3.head())
# Out:
#    global_id  PERIOD                                          WORK_NAME  \
# 0     351060    2022                      замена лифтового оборудования
# 1     430496    2022                      замена лифтового оборудования
# 2     348580    2022  ремонт внутридомовых инженерных систем водоотв...
# 3     348581    2022  ремонт внутридомовых инженерных систем теплосн...
# 4     348578    2022  ремонт внутридомовых инженерных систем холодно...
#
#    NUM_ENTRANCE ElevatorNumber PLAN_DATE_START PLAN_DATE_END FACT_DATE_START  \
# 0           1.0              1      2022-07-15    28.08.2022      27.06.2022
# 1           1.0              1      2022-09-30    14.10.2022      30.09.2022
# 2           NaN            NaN      2022-02-21    20.06.2022      01.02.2022
# 3           NaN            NaN      2022-04-21    10.07.2022      07.05.2022
# 4           NaN            NaN      2022-02-21    20.06.2022      01.02.2022
#
# ...

# %% [markdown]
# Переименование столбца "UNOM" в "unom" для объединения с датасетом X_1 по этому столбцу

# %%
X_3 = X_3.rename(columns={'UNOM': 'unom'})

# %% [markdown]
# Количестов работ на дом - unom

# %%
grouped_X_3= X_3.groupby('unom')['WORK_NAME'].size().reset_index(name='Работы_по_кап_ремонту')

# %%
print(grouped_X_3)
# Out:
#       unom  Работы_по_кап_ремонту
# 0      365                     13
# 1      367                     12
# 2      370                      1
# 3      376                      8
# 4      379                      1
# ..     ...                    ...
# 368  82032                      4
# 369  82033                      7
# 370  82036                      5
# 371  82037                      4
# 372  82038                      4
#
# [373 rows x 2 columns]

# %%
grouped_X_3.to_excel("E:\Data10\grouped_X_3.xlsx", index=False)

# %% [markdown]
# Переименование столбца "Address" в "Адрес" для объединения с датасетом X_1 по этому столбцу

# %%
X_3 = X_3.rename(columns={'Address': 'Адрес'})

# %% [markdown]
# Переименование столбца "PLAN_DATE_START" в "Дата создания во внешней системе" для объединения с датасетом X_1 по этому столбцу

# %%
X_3 = X_3.rename(columns={'PLAN_DATE_START' : 'Дата создания во внешней системе'})

# %%
print(X_3.head())
# Out:
#    global_id  PERIOD                                          WORK_NAME  \
# 0     351060    2022                      замена лифтового оборудования
# 1     430496    2022                      замена лифтового оборудования
# 2     348580    2022  ремонт внутридомовых инженерных систем водоотв...
# 3     348581    2022  ремонт внутридомовых инженерных систем теплосн...
# 4     348578    2022  ремонт внутридомовых инженерных систем холодно...
#
#    NUM_ENTRANCE ElevatorNumber Дата создания во внешней системе PLAN_DATE_END  \
# 0           1.0              1                       2022-07-15    28.08.2022
# 1           1.0              1                       2022-09-30    14.10.2022
# 2           NaN            NaN                       2022-02-21    20.06.2022
# 3           NaN            NaN                       2022-04-21    10.07.2022
# 4           NaN            NaN                       2022-02-21    20.06.2022
#
# ...

# %%
X_3 ['Дата создания во внешней системе'] = pd.to_datetime(X_3 ['Дата создания во внешней системе'])

# %%
X_3['Дата создания во внешней системе'] = X_3['Дата создания во внешней системе'].astype(str)

# %%
X_3.to_excel('E:\Data10\X_3_11.xlsx', index=False, engine='openpyxl')

# %%
X_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747 entries, 0 to 1746
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   global_id                         1747 non-null   int64
#  1   PERIOD                            1747 non-null   int64
#  2   WORK_NAME                         1747 non-null   object
#  3   NUM_ENTRANCE                      285 non-null    float64
#  4   ElevatorNumber                    285 non-null    object
#  5   Дата создания во внешней системе  1747 non-null   object
#  6   PLAN_DATE_END                     1747 non-null   object
#  7   FACT_DATE_START                   1747 non-null   object
#  8   FACT_DATE_END                     1747 non-null   object
#  9   AdmArea                           1747 non-null   object
#  10  District                          1747 non-null   object
# ...

# %% [markdown]
# Подсчет количества пропущенных значений в каждом столбце

# %%
#X_3.isna().sum()

# %% [markdown]
# Выгрузка датасет X_4.1

# %%
X_4_1_xlsx = 'E:\Data10\X_4.1.xlsx'

# %% [markdown]
# Строк с индексом  1 назначено в качестве заголовком, т.к стр. инд.0 - пустая

# %%
X_4_1 = pd.read_excel(X_4_1_xlsx, header=1)

# %% [markdown]
# Проверка размерности датасета

# %%
X_4_1.shape
# Out:
# (29, 7)

# %% [markdown]
# Вывод первых 5 строк датасета

# %%
print(X_4_1.head())
# Out:
#    №\nп/п  Код                                       Наименование  \
# 0       1  105                              строительный контроль
# 1       2   26  ремонт подъездов, направленный на восстановлен...
# 2       3    9  ремонт фасада (замена оконных блоков, располож...
# 3       4  104  проведение экспертизы проектной документации п...
# 4       5   20                  разработка проектной документации
#
#   Наименование объекта общего имущества Тип работ   Группа работ  \
# 0                 Строительный контроль    Услуга  Стройконтроль
# 1                               Подъезд    Работа            СМР
# 2                  Фасад(оконные блоки)    Работа            СМР
# 3                 проведение экспертизы    Услуга            СМР
# 4     разработка проектной документации    Услуга            СМР
#
#   Сокращенное наименование работы
# 0                              СК
# 1                         Подъезд
# 2                            Окна
# 3           проведение экспертизы
# ...

# %% [markdown]
# Вывод общей информации по датасетй\у

# %%
X_4_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   №
# п/п                                  29 non-null     int64
#  1   Код                                    29 non-null     int64
#  2   Наименование                           29 non-null     object
#  3   Наименование объекта общего имущества  29 non-null     object
#  4   Тип работ                              29 non-null     object
#  5   Группа работ                           29 non-null     object
#  6   Сокращенное наименование работы        29 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 1.7+ KB

# %% [markdown]
# Подсчет количества пропущенных значений в каждом столбце

# %%
X_4_1.isna().sum()
# Out:
# №\nп/п                                   0
# Код                                      0
# Наименование                             0
# Наименование объекта общего имущества    0
# Тип работ                                0
# Группа работ                             0
# Сокращенное наименование работы          0
# dtype: int64

# %% [markdown]
# Выгрузка датасет X_4.2

# %%
X_4_2_xlsx = 'E:\Data10\X_4.2.xlsx'

# %%
X_4_2 = pd.read_excel(X_4_2_xlsx, engine = 'openpyxl')

# %% [markdown]
# Проверка размерности датасета

# %%
X_4_2.shape
# Out:
# (498, 16)

# %% [raw]
# Вывод первых 5 строк датасета

# %%
print(X_4_2.head())
# Out:
#         ID                                               NAME  PARENT_ID  \
# 0  3682661                   Ремонт кровельного покрытия дома   26352880
# 1  3682664                              Ремонт мусоропроводов   26352883
# 2  3682666  Ремонт электрооборудования (эл. щитков, замена...   26352883
# 3  3682669  Снятие показаний общедомового прибора учета (е...   26352866
# 4  3682671                         Техническая инвентаризация   26352866
#
#        LOGIN COL_1044  COL_1045 COL_1157 COL_1239  COL_4488  COL_4489  \
# 0  migration      NaN       NaN     Иное      4.8       NaN       NaN
# 1  migration      NaN       NaN     Иное     5.24       NaN       NaN
# 2  migration      NaN       NaN     Иное  5.24.16       NaN       NaN
# 3  migration      NaN       NaN     Иное     13.4       NaN       NaN
# 4  migration      NaN       NaN     Иное     13.4       NaN       NaN
#
#    COL_4764  COL_4923  COL_20060  COL_20061  COL_20062  COL_20063
# ...

# %% [markdown]
# Вывод общей информации по датасету

# %%
X_4_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         498 non-null    int64
#  1   NAME       498 non-null    object
#  2   PARENT_ID  498 non-null    int64
#  3   LOGIN      498 non-null    object
#  4   COL_1044   375 non-null    object
#  5   COL_1045   384 non-null    float64
#  6   COL_1157   313 non-null    object
#  7   COL_1239   498 non-null    object
#  8   COL_4488   200 non-null    float64
#  9   COL_4489   167 non-null    float64
#  10  COL_4764   498 non-null    int64
#  11  COL_4923   498 non-null    int64
#  12  COL_20060  498 non-null    int64
#  13  COL_20061  498 non-null    int64
#  14  COL_20062  168 non-null    float64
#  15  COL_20063  185 non-null    float64
# dtypes: float64(5), int64(6), object(5)
# memory usage: 62.4+ KB

# %% [markdown]
# Подсчет количества пропущенных значений в каждом столбце

# %%
X_4_2.isna().sum()
# Out:
# ID             0
# NAME           0
# PARENT_ID      0
# LOGIN          0
# COL_1044     123
# COL_1045     114
# COL_1157     185
# COL_1239       0
# COL_4488     298
# COL_4489     331
# COL_4764       0
# COL_4923       0
# COL_20060      0
# COL_20061      0
# COL_20062    330
# COL_20063    313
# dtype: int64

# %% [markdown]
# Выгрузка и чтерние датасета

# %%
X_5_xlsx = 'E:\Data10\X_5.xlsx'

# %%
X_5 = pd.read_excel(X_5_xlsx, engine = 'openpyxl')

# %% [markdown]
# Проверка размерности датасета

# %%
X_5.shape
# Out:
# (950, 3)

# %% [markdown]
# Вывод первых 5 строк датасета

# %%
print(X_5.head())
# Out:
#                                      id  \
# 0  001b91e9-2ac5-4949-bff0-bb51d4f3057c
# 1  0089fd48-aa7a-443d-85a5-00470285b076
# 2  016697a2-feef-4568-9629-3c9dddae3aea
# 3  02212d7e-3c4c-4e6a-8f6b-d4f8f1b82e72
# 4  0250d455-608a-4d63-9902-ebe3b82d0b67
#
#                                              name   system
# 0                         Нарушение в работе  АГВ  MOS_GAS
# 1  Проверить на загазованность дюкер Гольяновский  MOS_GAS
# 2   Разрушение асфальтового полотна вокруг ковера  MOS_GAS
# 3                Угроза взрыва; Запах газа в доме  MOS_GAS
# 4                               Запах газа от ГРП  MOS_GAS

# %% [markdown]
# Вывод общей информации по датасету

# %%
X_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      950 non-null    object
#  1   name    949 non-null    object
#  2   system  950 non-null    object
# dtypes: object(3)
# memory usage: 22.4+ KB

# %% [markdown]
# Подсчет количества пропущенных значений в каждом столбце

# %%
X_5.isna().sum()
# Out:
# id        0
# name      1
# system    0
# dtype: int64

# %%
X_5.nunique()
# Out:
# id        950
# name      791
# system     10
# dtype: int64

# %% [markdown]
# Объединение двух датасет  X_2 и X_3 по стообецу  unmo.

# %%
#Merged_X_2_3 = X_2.merge(X_3, on='unom', how='inner')

# %%
Merged_X_2_3 =pd.merge(X_2, X_3, on=['unom', 'Дата создания во внешней системе'])

# %%
Merged_X_2_3.head()
# Out:
#                    Наименование Источник Дата создания во внешней системе  \
# 0  Повреждение внутренней двери      EDC                       2022-04-21
# 1        Расхождение времени ПУ    ASUPR                       2022-05-21
# 2          Лифт требует ремонта      EDC                       2022-05-21
# 3       Поломка почтовых ящиков      EDC                       2022-05-21
# 4    Низкий уровень сигнала GSM    ASUPR                       2022-05-21
#
#                 Дата закрытия Округ  \
# 0  2022-04-21 21:24:52.502000   ВАО
# 1  2022-05-20 22:52:42.222000   ВАО
# 2  2023-04-05 01:00:33.987000   ВАО
# 3  2022-05-23 16:53:30.502000   ВАО
# 4  2022-05-21 02:34:53.929000   ВАО
#
#                                              Адрес_x   unom  \
# 0  Российская Федерация, город Москва, внутригоро...  19980
# 1  Российская Федерация, город Москва, внутригоро...  26890
# 2  Российская Федерация, город Москва, внутригоро...  19211
# ...

# %%
Merged_X_2_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1323 entries, 0 to 1322
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Наименование                        1323 non-null   object
#  1   Источник                            1323 non-null   object
#  2   Дата создания во внешней системе    1323 non-null   object
#  3   Дата закрытия                       1323 non-null   object
#  4   Округ                               1323 non-null   object
#  5   Адрес_x                             1323 non-null   object
#  6   unom                                1323 non-null   int64
#  7   Дата и время завершения события во  513 non-null    object
#  8   global_id                           1323 non-null   int64
#  9   PERIOD                              1323 non-null   int64
#  10  WORK_NAME                           1323 non-null   object
# ...

# %%
Merged_X_2_3.to_excel('E:\Data10\Merged_X_2_31.xlsx', index=False, engine='openpyxl')

# %%
J

# %%
merged_Grouped_X_2_3 = grouped_X_2.merge(grouped_X_3, on='unom', how='outer') 
merged_Grouped_X_2_3.fillna(0, inplace=True)

# %%
merged_Grouped_X_2_3.to_excel("E:\Data10\merged_Grouped_X_2_3.xlsx", index=False)
